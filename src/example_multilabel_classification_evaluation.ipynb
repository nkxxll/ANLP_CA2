# %%
import sys
sys.path.append("./scripts")
from scripts.multilabel_classification_evaluator import MultiLabelEvaluator



import json
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score, hamming_loss, jaccard_score
from IPython.display import display


annotations_path = "../data/lstudio_annotations.json"
results_path = "./scripts/results/results-v3-2025-02-13T15_39_11.853550-nall-llama3.2.json"

evaluator = MultiLabelEvaluator(annotations_path, results_path)

# %%
metrics_df = evaluator.evaluate()
display(metrics_df)
# Out:
# c:\Users\cedri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 in samples with no true or predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                         precision    recall  f1-score support
# bugs                     0.459016  0.848485  0.595745    33.0
# gamemode                 0.492537   0.52381  0.507692    63.0
# gameplay                 0.718310  0.703448  0.710801   145.0
# hardware_requirements    0.500000     0.375  0.428571    16.0
# online_play              0.534884      0.46  0.494624    50.0
# price                    0.666667  0.615385      0.64    52.0
# seasonal_content         0.250000  0.222222  0.235294     9.0
# sound                    0.500000  0.454545   0.47619    11.0
# story                    0.500000  0.454545   0.47619    44.0
# support                  0.375000       0.6  0.461538    35.0
# updates                  0.551724  0.333333  0.415584    48.0
# visuals                  0.558140  0.666667  0.607595    36.0
# micro avg                0.558140  0.575646  0.566757   542.0
# macro avg                0.508856  0.521453  0.504152   542.0
# weighted avg             0.570469  0.575646  0.564321   542.0
# samples avg              0.529012   0.57038  0.515076   542.0
# Overall Accuracy         0.836420         -         -       -
# Hamming Loss             0.163580         -         -       -
# Jaccard Score            0.414762         -         -       -
# Avg Correct per Review   0.607417         -         -       -
# Micro F1                 0.566757         -         -       -
# Macro F1                 0.504152         -         -       -
# Micro Precision          0.558140         -         -       -
# Macro Precision          0.508856         -         -       -
# Micro Recall             0.575646         -         -       -
# Macro Recall             0.521453         -         -       -

# %%
review_metrics = evaluator.review_metrics()
display(review_metrics)
# Out:
#      Review ID                                        Review Text  \
# 0          218  game be good but since the last patch a few da...
# 1          738  ehh feel cool for the first hour or so then th...
# 2         1001  im a fan of harry potter and i have my doubt w...
# 3         2891  that be really a perfect fps game by valve i t...
# 4         3419  valve completely ruin the game in the same vai...
# ..         ...                                                ...
# 238      93817  this be the exact same fucking game as last ye...
# 239      93822  if this game be an nba player it be dillon bro...
# 240      93887                can not play mycareer offline score
# 241      94474  the game be pretty simular to the last copy of...
# 242      94493  if you be play on pc and you already have you ...
#
#                                            True Topics  \
# 0                                               [bugs]
# 1                                    [story, gameplay]
# 2                                  [visuals, gameplay]
# 3                                  [gameplay, updates]
# 4    [price, updates, online_play, support, visuals...
# ..                                                 ...
# 238  [price, gameplay, updates, hardware_requirements]
# 239                                          [support]
# 240                                             [bugs]
# 241                               [price, online_play]
# 242                                          [updates]
#
#                                       Predicted Topics  \
# 0                                                   []
# 1    [price, gameplay, updates, support, visuals, b...
# 2                           [visuals, gameplay, sound]
# 3    [price, gameplay, sound, updates, support, vis...
# 4          [gameplay, updates, support, visuals, bugs]
# ..                                                 ...
# 238                   [story, sound, updates, support]
# 239            [price, gameplay, sound, visuals, bugs]
# 240            [gamemode, bugs, gameplay, online_play]
# 241   [visuals, gameplay, bugs, hardware_requirements]
# 242         [price, updates, support, story, gamemode]
#
#      Correctly Classified Topics  Total Topics  Accuracy per Review  \
# 0                              0             1                 0.00
# 1                              2             2                 1.00
# 2                              2             2                 1.00
# 3                              2             2                 1.00
# 4                              3             6                 0.50
# ..                           ...           ...                  ...
# 238                            1             4                 0.25
# 239                            0             1                 0.00
# 240                            1             1                 1.00
# 241                            0             2                 0.00
# 242                            1             1                 1.00
#
#      Jaccard Score
# 0         0.000000
# 1         0.250000
# 2         0.666667
# 3         0.222222
# 4         0.375000
# ..             ...
# 238       0.142857
# 239       0.000000
# 240       0.250000
# 241       0.000000
# 242       0.200000
#
# [243 rows x 8 columns]
